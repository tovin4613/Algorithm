# %%
import sys
from collections import deque

def fire_BFS(graph, queue):

    while queue:
        x, y = queue.popleft()
        
        for i in range(4):
            nx = x + dx[i]
            ny = y + dy[i]
            if (nx < 0) or (nx >= h) or (ny < 0) or (ny >= w):
                continue
            if fire_visited[nx][ny] >= 1:
                continue
            queue.append((nx, ny))
            fire_visited[nx][ny] = fire_visited[x][y] + 1

def user_BFS(graph, queue):

    while queue:
        x, y = queue.popleft()
        
        for i in range(4):
            nx = x + dx[i]
            ny = y + dy[i]
            if (nx < 0) or (nx >= h) or (ny < 0) or (ny >= w):
                return user_visited[x][y]
            if (user_visited[nx][ny] >= 1) or (fire_visited[nx][ny] <= user_visited[nx][ny]):
                continue
            queue.append((nx, ny))
            user_visited[nx][ny] = user_visited[x][y] + 1
    return 'IMPOSSIBLE'

k = int(input())
dx = [0, 0, 1, -1]
dy = [1, -1, 0, 0]

fire_queue = deque()
user_queue = deque()
for i in range(k):
    graph = []
    w, h = map(int, input().split())
    fire_visited = [[0 for j in range(w)] for i in range(h)]
    user_visited = [[0 for j in range(w)] for i in range(h)]
    for j in range(h):
        graph.append(list(str(input())))

    for j in range(h):
        for k in range(w):
            if(graph[j][k] == '#' or graph[j][k] == '*'):
                fire_visited[j][k] = 1
                user_visited[j][k] = 1
            if(graph[j][k] == '*'):
                fire_queue.append((j, k))
            if(graph[j][k] == '@'):
                user_queue.append((j, k))
                user_visited[j][k] = 1

    fire_BFS(graph, fire_queue)
    print(user_BFS(graph, user_queue))
